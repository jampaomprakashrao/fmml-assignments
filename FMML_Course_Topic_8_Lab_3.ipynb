# %% [markdown]
# <a href="https://colab.research.google.com/github/jampaomprakashrao/fmml-assignments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-02 05:52:48--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   108MB/s    in 0.6s
#
# 2023-05-02 05:52:50 (108 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12513  1802.06368v1  Embedding graph nodes into a vector space can ...    cs
# 22279  1511.06120v1  In clinical and neuroscientific studies, syste...  stat
# 36425   1401.3475v1  Prime implicates and prime implicants have pro...    cs
# 12296  1711.04315v1  Several multiscale methods account for sub-gri...    cs
# 17723  1802.04200v1  We investigate end-to-end speech-to-text trans...    cs
# ...             ...                                                ...   ...
# 35889   1304.5159v1  A key challenge in non-cooperative multi-agent...    cs
# 11456  1602.04915v2  We show that gradient descent converges to a l...  stat
# 23059  1802.10526v1  This is full length article (draft version) wh...  stat
# 12573  1803.00992v1  Many machine learning systems rely on data col...  stat
# 8845   1512.04419v1  Distributional semantic models provide vector ...    cs
#
#                                                    title  year  \
# 12513  Node Centralities and Classification Performan...  2018
# 22279      The Kernel Two-Sample Test for Brain Networks  2015
# 36425  Prime Implicates and Prime Implicants: From Pr...  2014
# 12296  A machine learning approach for efficient unce...  2017
# 17723  End-to-End Automatic Speech Translation of Aud...  2018
# ...                                                  ...   ...
# 35889  Interactive POMDP Lite: Towards Practical Plan...  2013
# 11456           Gradient Descent Converges to Minimizers  2016
# 23059  Application of Rényi and Tsallis Entropies to ...  2018
# 12573  Label Sanitization against Label Flipping Pois...  2018
# 8845   Sentence Entailment in Compositional Distribut...  2015
#
#                                                 keywords
# 12513  [embedding, embedding, algorithms, processing,...
# 22279  [neuroscientific, systematic, differences, pop...
# 36425  [implicates, implicants, artificial, intellige...
# 12296  [multiscale, functions, multiscale, functions,...
# 17723  [investigate, translation, audiobooks, specifi...
# ...                                                  ...
# 35889  [challenge, cooperative, developing, efficient...
# 11456  [converges, minimizer, initialization, dynamic...
# 23059  [discussed, identification, collections, numer...
# 12573  [collected, untrusted, algorithms, poisoning, ...
# 8845   [distributional, representations, gathering, o...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12513    [embedding, embedding, algorithms, processing,...
# 22279    [neuroscientific, systematic, differences, pop...
# 36425    [implicates, implicants, artificial, intellige...
# 12296    [multiscale, functions, multiscale, functions,...
# 17723    [investigate, translation, audiobooks, specifi...
#                                ...
# 11652    [clustering, frequently, clustering, community...
# 13192    [perturbation, inequalities, perturbation, app...
# 32655    [framework, computing, complexity, recovering,...
# 21953    [applications, especially, scenarios, phenomen...
# 19918    [computational, reasoning, probabilistic, pres...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8816 words.
# Out of those 4620 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="eaa84520-42c3-4260-8d14-1cd9380ccfe6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eaa84520-42c3-4260-8d14-1cd9380ccfe6")) {                    Plotly.newPlot(                        "eaa84520-42c3-4260-8d14-1cd9380ccfe6",                        [{"x":["performance","embedding","algorithms","centrality","systematic","classification","characterizing","characterize","experimental","experiments","properties","processing","processes","neuroimaging","computation","discriminate","represented","frequency","populations","investigated","simulation","differences","additionally","approaches","intermediate","algorithmic","considerations","different","classifier","providing","complexity","definition","abductive","knowledge","generating","artificial","description","expressions","recognizing","intelligence","recognition","appropriately","considering","satisfies","perfectly","desirable","reasoning","syntactic","computational","propositional","evaluated","characteristic","definitions","theoretic","compilation","potential","generalizes","multiscale","permeability","introduce","modularity","specifically","functions","advantage","efficient","quantification","promising","subsequent","predictor","redundancy","uncertainty","estimation","attribute","realizations","available","investigate","distribute","augmented","challenged","translation","transcription","automatic","capabilities","distribution","refocusing","resolution","effective","fractional","controlled","capturing","implementations","information","directional","explicitly","appearance","anticipation","assessment","temporally","localizing","spatially","environment","outperforms","recurrent","triggering","localization","anticipating","attention","consistently","consisting","accidents","baselines","interaction","containing","augmentation","resulting","synthetically","simulated","substantially","availability","components","including","detection","efficiency","convergence","robustness","geometric","algorithm","numerically","influential","extracting","applicable","dimensional","application","understandings","principal","especially","exchangeable","guarantees","framework","probability","pioneering","particular","demonstrate","instantiating","increases","generative","exchangeability","assumption","alternative","traditionally","stationary","invariant","coefficients","compression","expansion","coordinate","decomposition","technique","essential","orthonormal","relations","deterministic","sufficiently","asymmetry","independently","inferring","dimensionality","distributions","covariance","stochastic","structure","variables","observations","established","minimizing","lagrangian","projected","regression","splitting","extracted","hyperspectral","drawbacks","furthermore","determine","significantly","conducted","multinomial","applications","inefficacy","automatically","constrained","university","regressor","optimization","multiplier","principle","generated","likelihoods","likelihood","parameters"],"y":[853,116,590,3,35,544,26,42,415,601,196,270,105,10,142,15,86,54,11,53,72,63,53,429,23,42,10,736,142,94,250,33,4,366,83,141,80,35,38,83,368,7,67,11,6,32,140,42,307,26,151,31,18,43,4,168,27,13,2,328,9,165,231,90,400,15,112,21,13,17,83,199,40,3,300,159,6,43,3,113,10,180,55,234,2,115,261,8,45,40,35,694,18,64,62,3,44,15,13,21,114,249,140,2,66,3,164,35,47,3,59,91,48,19,142,10,54,39,28,101,225,337,184,109,111,67,832,13,9,57,50,197,217,1,33,112,2,62,536,153,0,273,565,4,55,114,1,68,99,25,26,65,37,46,17,20,72,269,75,1,80,41,11,5,42,28,59,123,24,119,348,136,68,61,65,11,22,112,18,123,11,16,150,72,280,73,3,421,1,193,67,19,7,328,2,47,155,1,70,240],"type":"bar"},{"x":["performance","embedding","algorithms","centrality","systematic","c ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4620,), (4620, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8108333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Developing</span> <span style='background-color:rgba(0, 255, 0, 0.4296875);'>Knowledge</span> <span style=''>enhanced</span> <span style=''>Chronic</span> <span style=''>Disease</span> <span style=''>Risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <span style=''>Models</span> <span style=''>from</span> <span style=''>Regional</span> <span style=''>EHR</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>Repositories</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Precision</span> <span style=''>medicine</span> <span style=''>requires</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precision</span> <span style=''>disease</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>models</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>there</span> <span style=''>have</span> <span style=''>been</span> <span style=''>a</span> <span style=''>lot</span> <span style=''>well</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>established</span> <span style=''>(inter</span> <span style=''>)national</span> <span style=''>risk</span> <span style=''>models</span> <span style=''>but</span> <span style=''>when</span> <span style=''>applying</span> <span style=''>them</span> <span style=''>into</span> <span style=''>the</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>becomes</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>unsatisfactory</span> <span style=''>To</span> <span style=''>address</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.736842105263158);'>localization</span> <span style=''>issue</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>exploits</span> <span style=''>the</span> <span style=''>way</span> <span style=''>to</span> <span style=''>develop</span> <span style='background-color:rgba(0, 255, 0, 0.4296875);'>knowledge</span> <span style=''>enhanced</span> <span style='background-color:rgba(0, 255, 0, 0.31428571428571417);'>localized</span> <span style=''>risk</span> <span style=''>models</span> <span style=''>On</span> <span style=''>the</span> <span style=''>one</span> <span style=''>hand</span> <span style=''>we</span> <span style=''>tune</span> <span style=''>models</span> <span style=''>by</span> <span style=''>learning</span> <span style=''>from</span> <span style=''>regional</span> <span style='background-color:rgba(0, 255, 0, 0.41176470588235303);'>Electronic</span> <span style=''>Health</span> <span style=''>Record</span> <span style=''>(EHR)</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>repositories</span> <span style=''>and</span> <span style=''>on</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style=''>we</span> <span style=''>propose</span> <span style='background-color:rgba(0, 255, 0, 0.4296875);'>knowledge</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>injection</span> <span style=''>into</span> <span style=''>the</span> <span style=''>EHR</span> <span style=''>data</span> <span style=''>learning</span> <span style=''>process</span> <span style=''>For</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>we</span> <span style=''>leverage</span> <span style=''>the</span> <span style=''>Pooled</span> <span style=''>Cohort</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Equations</span> <span style=''>(PCE</span> <span style=''>as</span> <span style='b ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Compressed</span> <span style=''>sensing</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressed</span> <span style=''>sensing</span> <span style=''>whose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>is</span> <span style=''>to</span> <span style=''>recover</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>sparse</span> <span style=''>signal</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrupted</span> <span style=''>by</span> <span style=''>outliers</span> <span style=''>A</span> <span style=''>new</span> <span style=''>sparse</span> <span style=''>Bayesian</span> <span style=''>learning</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressed</span> <span style=''>sensing</span> <span style=''>The</span> <span style=''>basic</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>is</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>and</span> <span style=''>remove</span> <span style=''>the</span> <span style=''>outliers</span> <span style=''>from</span> <span style=''>sparse</span> <span style=''>signal</span> <span style=''>recovery</span> <span style=''>To</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style=''>identify</span> <span style=''>the</span> <span style=''>outliers</span> <span style=''>we</span> <span style=''>employ</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>indicator</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>to</span> <span style=''>indicate</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>are</span> <span style=''>outliers</span> <span style=''>These</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>indicator</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>are</span> <span style=''>treated</span> <span style=''>as</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>and</span> <span style=''>assigned</span> <span style=''>a</span> <span style=''>beta</span> <span style=''>process</span> <span style=''>prior</span> <span style=''>such</span> <span style=''>that</span> <span style=''>their</span> <span style=''>values</span> <span style=''>are</span> <span style=''>confined</span> <span style=''>to</span> <span style=''>be</span> <span style=''>binary</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>inverse</span> <span style=''>Gamma</span> <span style=''>prior</span> <span style=''>is</span> <span style=''>imposed</span> <span style=''>on</span> <span style=''>the</span> <span style=''>sparse</span> <span style=''>signal</span> <span style=''>to</span> <span style=''>promote</span> <span style=''>sparsity</span> <span style=''>Based</span> <span style=''>on</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Saliency</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>Benchmarking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Separating</span> <span style=''>Models</span> <span style=''>Maps</span> <span style=''>and</span> <span style=''>Metrics</span> <br/><br/><span style=''>The</span> <span style=''>field</span> <span style=''>of</span> <span style=''>fixation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>is</span> <span style=''>heavily</span> <span style=''>model</span> <span style=''>driven</span> <span style=''>with</span> <span style=''>dozens</span> <span style=''>of</span> <span style=''>new</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.38235294117647056);'>published</span> <span style=''>every</span> <span style=''>year</span> <span style=''>However</span> <span style=''>progress</span> <span style=''>in</span> <span style=''>the</span> <span style=''>field</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>judge</span> <span style=''>because</span> <span style=''>models</span> <span style=''>are</span> <span style=''>compared</span> <span style=''>using</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3684210526315789);'>inconsistent</span> <span style=''>metrics</span> <span style=''>As</span> <span style=''>soon</span> <span style=''>as</span> <span style=''>a</span> <span style=''>saliency</span> <span style=''>map</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimized</span> <span style=''>for</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>metric</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.7674418604651163);'>penalized</span> <span style=''>by</span> <span style=''>other</span> <span style=''>metrics</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principled</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>benchmarking</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>separate</span> <span style=''>the</span> <span style=''>notions</span> <span style=''>of</span> <span style=''>saliency</span> <span style=''>models</span> <span style=''>and</span> <span style=''>saliency</span> <span style=''>maps</span> <span style=''>We</span> <span style=''>define</span> <span style=''>a</span> <span style=''>saliency</span> <span style=''>model</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>of</span> <span style=''>fixation</span> <span style=''>density</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>and</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>Bayesian</span> <span style=''>decision</span> <span style=''>theory</span> <span style=''>a</span> <span style=''>saliency</span> <span style=''>map</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style=''>metric</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>the</span> <span style=''>model</span> <span style=''>density</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizes</span> <span style=''>the</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Raiders</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Lost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Architecture</span> <span style=''>Kernels</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Parameter</span> <span style=''>Spaces</span> <br/><br/><span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>we</span> <span style=''>must</span> <span style=''>often</span> <span style=''>search</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differing</span> <span style=''>numbers</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>For</span> <span style=''>instance</span> <span style=''>we</span> <span style=''>may</span> <span style=''>wish</span> <span style=''>to</span> <span style=''>search</span> <span style=''>over</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>with</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>number</span> <span style=''>of</span> <span style=''>layers</span> <span style=''>To</span> <span style=''>relate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>data</span> <span style=''>gathered</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>we</span> <span style=''>define</span> <span style=''>a</span> <span style=''>new</span> <span style=''>kernel</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>spaces</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style=''>includes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>are</span> <span style=''>relevant</span> <span style=''>in</span> <span style=''>a</span> <span style=''>given</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>kernel</span> <span style=''>improves</span> <span style=''>model</span> <span style=''>quality</span> <span style=''>and</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>results</span> <span style=''>over</span> <span style=''>several</span> <span style=''>simpler</span> <span style=''>baseline</span> <span style=''>kernels</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12504478681476172)
# 	segmentation (0.07273378717305626)
# 	architecture (0.0881404514510928)
# 	knowledge (0.13113579362235758)
# 	experimental (0.14869222500895737)
# 	information (0.24865639555714797)
# 	detection (0.12074525259763526)
# 	different (0.26370476531709064)
# 	convolutional (0.13292726621282694)
# 	recognition (0.13185238265854532)
#
# Some Statistics words are:
# 	variables (0.13240418118466898)
# 	variational (0.10004977600796416)
# 	stochastic (0.1368840219014435)
# 	statistical (0.15181682429069188)
# 	estimation (0.1712294673967148)
# 	distribution (0.18466898954703834)
# 	theoretical (0.1483325037332006)
# 	inference (0.1871577899452464)
# 	dimensional (0.1866600298656048)
# 	regression (0.17869586859133899)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1dcc45d0-c899-4b78-9f95-6d61a4a41795" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1dcc45d0-c899-4b78-9f95-6d61a4a41795")) {                    Plotly.newPlot(                        "1dcc45d0-c899-4b78-9f95-6d61a4a41795",                        [{"x":["performance","embedding","algorithms","centrality","systematic","classification","characterizing","characterize","experimental","experiments","properties","processing","processes","neuroimaging","computation","discriminate","represented","frequency","populations","investigated","simulation","differences","additionally","approaches","intermediate","algorithmic","considerations","different","classifier","providing","complexity","definition","abductive","knowledge","generating","artificial","description","expressions","recognizing","intelligence","recognition","appropriately","considering","satisfies","perfectly","desirable","reasoning","syntactic","computational","propositional","evaluated","characteristic","definitions","theoretic","compilation","potential","generalizes","multiscale","permeability","introduce","modularity","specifically","functions","advantage","efficient","quantification","promising","subsequent","predictor","redundancy","uncertainty","estimation","attribute","realizations","available","investigate","distribute","augmented","challenged","translation","transcription","automatic","capabilities","distribution","refocusing","resolution","effective","fractional","controlled","capturing","implementations","information","directional","explicitly","appearance","anticipation","assessment","temporally","localizing","spatially","environment","outperforms","recurrent","triggering","localization","anticipating","attention","consistently","consisting","accidents","baselines","interaction","containing","augmentation","resulting","synthetically","simulated","substantially","availability","components","including","detection","efficiency","convergence","robustness","geometric","algorithm","numerically","influential","extracting","applicable","dimensional","application","understandings","principal","especially","exchangeable","guarantees","framework","probability","pioneering","particular","demonstrate","instantiating","increases","generative","exchangeability","assumption","alternative","traditionally","stationary","invariant","coefficients","compression","expansion","coordinate","decomposition","technique","essential","orthonormal","relations","deterministic","sufficiently","asymmetry","independently","inferring","dimensionality","distributions","covariance","stochastic","structure","variables","observations","established","minimizing","lagrangian","projected","regression","splitting","extracted","hyperspectral","drawbacks","furthermore","determine","significantly","conducted","multinomial","applications","inefficacy","automatically","constrained","university","regressor","optimization","multiplier","principle","generated","likelihoods","likelihood","parameters","inference","invertible","restrictive","appropriate","combination","gaussians","approximate","parameter","factorized","generally","underlying","transformation","generalized","formalism","approximation","multivariate","parametric","procedure","solutions","separable","previously","extension","penalties","boltzmann","communities","regularized","statistical","divergences","efficiently","synthetic","equivalent","respectively","regularizers","dimensions","divergence","naturally","alternate","depending","classical","regularization","reference","regularizer","projections","illustrate","instantiate","transport","improvement","variations","implementation","optimizations","exploited","convolved","increased","prototypes","classifiers"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	pioneering
# 	proteomics
# 	precludes
# 	magnetoencephalographic
# 	minibatches
# 	dermatological
# 	tractably
# 	parameterizing
# 	underpowered
# 	monetization
# 	purchases
# 	abnormally
# 	anchoring
# 	beautiful
# 	consolidation
# 	curvatures
# 	roadworks
# 	modulating
# 	subsampling
# 	statistician
# Some words which never appear in Statistics papers:
# 	abductive
# 	propositional
# 	compilation
# 	permeability
# 	refocusing
# 	anticipation
# 	localizing
# 	anticipating
# 	accidents
# 	unimportant
# 	minkowski
# 	exemplified
# 	accelerometer
# 	smartphones
# 	synthesize
# 	protecting
# 	structuring
# 	gridworld
# 	realworld
# 	evaluators

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.074085459575777e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7541666666666667
